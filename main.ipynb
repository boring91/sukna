# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import get_result_df, load_data

file_id = '15iw-HH19cS_gFArQhAxGmHdDf9Y7m9_nU4NcZIyc_Z8'
service_account_file_path = 'service_account.json'
df = load_data(file_id, service_account_file_path, 1000)
df.columns
# Out:
# Index(['Timestamp', 'intermediary_number', 'gender', 'clan_type', 'full_name',
#        'اسم الفخذ ( الاسم اللي يكون قبل اسم القبيلة)', 'family_nature',
#        'nationality_type', 'province', 'male_city', 'رقم جوال للتواصل',
#        'date_of_birth', 'marital_status', 'job', 'height', 'weight',
#        'height_weight_details', 'skin_color', 'attractiveness_level',
#        'religiosity_level', 'morality_level', 'etiquette_level',
#        'health_status', 'smoking', 'financial_status',
#        'educational_qualification', 'male_description_extra',
#        'اسم القبيلة للطرف الثاني (الزوجة)', 'family_nature', 'clan_type',
#        'marriage_type', 'nationality_type', 'province', 'accommodation_type',
#        'age', 'marital_status', 'job', 'height', 'weight', 'skin_color',
#        'beauty_level', 'religiosity_level', 'morality_level',
#        'etiquette_level', 'hijab_type', 'health_status', 'smoking',
# ...

# %%
from main import generate_gender_df

males_df, md_df, mc_df = generate_gender_df(df, 'male')

# %%
md_df.columns
# Out:
# Index(['intermediary_number', 'clan_type', 'full_name',
#        'اسم الفخذ ( الاسم اللي يكون قبل اسم القبيلة)', 'family_nature',
#        'nationality_type', 'province', 'male_city', 'رقم جوال للتواصل',
#        'date_of_birth', 'marital_status', 'job', 'height', 'weight',
#        'height_weight_details', 'skin_color', 'attractiveness_level',
#        'religiosity_level', 'morality_level', 'etiquette_level',
#        'health_status', 'smoking', 'financial_status',
#        'educational_qualification', 'male_description_extra', 'row_number'],
#       dtype='object')

# %%
females_df, fd_df, fc_df = generate_gender_df(df, 'female')

# %%
females_df
# Out:
#   clan_type full_name اسم الفخذ ( الاسم اللي يكون قبل اسم القبيلة)  \
# 0      with       try                                        rtyyy
# 1      with      ytyh                                        hgjhk
#
#   family_nature nationality_type         province female_city  \
# 0           حضر           سعودية  المنطقة الشرقية        jhgj
# 1           بدو           سعودية       منطقة حائل      khjkhj
#
#   رقم جوال للتواصل date_of_birth               marital_status  ...  \
# 0       0511112222    10/28/2002                          بكر  ...
# 1       0511112222     10/1/2001  مطلقة قبل الدخلة (فسخ ملكة)  ...
#
#       skin_color attractiveness_level religiosity_level morality_level  \
# 0  not_important        not_important     not_important  not_important
# 1              1                 5, 3             10, 7           5, 3
#
#     etiquette_level  health_status        smoking financial_status  \
# 0     not_important  not_important  not_important    not_important
# ...

# %%
fd_df.columns
# Out:
# Index(['intermediary_number', 'clan_type', 'full_name',
#        'اسم الفخذ ( الاسم اللي يكون قبل اسم القبيلة)', 'family_nature',
#        'nationality_type', 'province', 'female_city', 'رقم جوال للتواصل',
#        'date_of_birth', 'marital_status', 'job', 'height', 'weight',
#        'height_weight_details', 'skin_color', 'beauty_level',
#        'religiosity_level', 'morality_level', 'etiquette_level', 'hijab_type',
#        'health_status', 'smoking', 'financial_status',
#        'educational_qualification', 'female_description_extra', 'row_number'],
#       dtype='object')

# %%
fc_df.columns
# Out:
# Index(['اسم القبيلة للطرف الثاني (الزوج)', 'family_nature', 'clan_type',
#        'marriage_type', 'nationality_type', 'province', 'accommodation_type',
#        'age', 'marital_status', 'job', 'height', 'weight', 'skin_color',
#        'attractiveness_level', 'religiosity_level', 'morality_level',
#        'etiquette_level', 'health_status', 'smoking', 'financial_status',
#        'educational_qualification', 'female_condition_extra'],
#       dtype='object')

# %%
print('Male description:')
print(md_df.iloc[0])
print()

print('Male conditions:')
print(mc_df.iloc[0])
print()

print('Female description:')
print(fd_df.iloc[0])
print()

print('Female conditions:')
print(fc_df.iloc[0])
print()
# Out:
# Male description:
# intermediary_number                                    05110000
# clan_type                                                  with
# full_name                                                  eeee
# اسم الفخذ ( الاسم اللي يكون قبل اسم القبيلة)               qqqq
# family_nature                                               حضر
# nationality_type                                          سعودي
# province                                           منطقة الرياض
# male_city                                                  dddd
# رقم جوال للتواصل                                     0511111111
# date_of_birth                                         7/15/1990
# marital_status                                  مطلق بدون أبناء
# job                                                        أهلي
# height                                              متوسط الطول
# weight                                              متوسط الوزن
# ...

# %%
from main import compute_match

compute_match(md_df, mc_df, fd_df, fc_df, 0, 1)
# Out:
# (0.7777777777777778,
#  {'family_nature': 1,
#   'nationality_type': 1,
#   'marital_status': 1,
#   'job': 1,
#   'height': 1,
#   'weight': 1,
#   'skin_color': 1,
#   'religiosity_level': 1,
#   'morality_level': 1,
#   'etiquette_level': 1,
#   'health_status': 1,
#   'smoking': 1,
#   'financial_status': 1,
#   'educational_qualification': 1,
#   'beauty_level': 1,
#   'hijab_type': 1,
#   'province': 1,
#   'accommodation_type': 1,
#   'age': 1},
#  {'family_nature': 0,
#   'nationality_type': 1,
#   'marital_status': 0,
#   'job': 0,
#   'height': 0,
#   'weight': 1,
#   'skin_color': 0,
#   'attractiveness_level': 0,
#   'religiosity_level': 1,
#   'morality_level': 0,
#   'etiquette_level': 1,
#   'health_status': 1,
#   'smoking': 0,
#   'financial_status': 1,
#   'educational_qualification': 1,
#   'province': 1,
#   'accommodation_type': 1,
#   'age': 1})

# %%
from main import get_result_df

get_result_df()
# Out:
#    رقم الصف للرجل اسم الرجل رقم الوسيط للرجل المدينة للرجل  \
# 0               1      eeee         05110000          dddd
# 1               1      eeee         05110000          dddd
#
#   تفاصيل الطول والوزن للرجل معلومات إضافية للرجل شروط إضافية للرجل  \
# 0                       123                  ggg             uuuuu
# 1                       123                  ggg             uuuuu
#
#   طبيعة العائلة (الرجل) نوع الجنسية (الرجل) الحالة الاجتماعية (الرجل)  ...  \
# 0                                                                      ...
# 1                                                                      ...
#
#   درجة الخلق (الفتاة) درجة الذرابة (الفتاة) الحالة الصحية (الفتاة)  \
# 0
# 1                   x
#
#   التدخين (الفتاة) الحالة المادية (الفتاة) المؤهل الدراسي (الفتاة)  \
# 0
# 1                x
#
#   المنطقة (الفتاة) نوع السكن (الفتاة) العمر (الفتاة) نسبة التوافق
# 0                                                      100.000000
# ...

# %%
from main import main

main()
# Out:
#    رقم الصف للرجل اسم الرجل رقم الوسيط للرجل المدينة للرجل  \
# 0               1      eeee         05110000          dddd
# 1               1      eeee         05110000          dddd
#
#   تفاصيل الطول والوزن للرجل معلومات إضافية للرجل شروط إضافية للرجل  \
# 0                       123                  ggg             uuuuu
# 1                       123                  ggg             uuuuu
#
#   طبيعة العائلة (الرجل) نوع الجنسية (الرجل) الحالة الاجتماعية (الرجل)  ...  \
# 0                                                                      ...
# 1                                                                      ...
#
#   درجة الخلق (الفتاة) درجة الذرابة (الفتاة) الحالة الصحية (الفتاة)  \
# 0
# 1                   x
#
#   التدخين (الفتاة) الحالة المادية (الفتاة) المؤهل الدراسي (الفتاة)  \
# 0
# 1                x
#
#   المنطقة (الفتاة) نوع السكن (الفتاة) العمر (الفتاة) نسبة التوافق
# 0                                                      100.000000
# ...
